# %% [markdown]
# <a href="https://colab.research.google.com/github/MarlonGrandy/LSTMMusicGeneration/blob/main/LSTMMusicGenerationPipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# import statements
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from music21 import converter, instrument, note, chord, stream, duration
import glob
import os
from itertools import chain
import copy
import numpy as np
from tensorflow.keras.callbacks import LambdaCallback
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from keras.layers import CuDNNLSTM, Bidirectional
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from numpy import argmax
from fractions import Fraction
import gc
import random
import keras.utils

# %%
def data_extractor(directory):
    """
    Summary:
    Function converts midi files to metadata and appends nested metadata lists into one large list
    composed of all the songs in the dataset.

    Parameters:
    directory: String representation of directory where midi files are located

    Returns:
    list: sequential midi file metadata
    """
    notes = []
    offsets = []
    durations = []
    for file in glob.glob(directory):
        mid = converter.parse(file)
        notes_to_parse = None
        prev_offset = 0

        try:
            s2 = instrument.partitionByInstrument(mid)
            notes_to_parse = s2.parts[1].recurse()

        except:
            notes_to_parse = mid.flat.notes

        for i, element in enumerate(notes_to_parse):
            if isinstance(element, note.Note):
                notes.append(str(element.pitch))
                print(element.pitch)

                durations.append(str(element.quarterLength))

                offset_dif = float(element.offset - prev_offset)

                offsets.append(round(offset_dif, 3))
                prev_offset = element.offset

            elif isinstance(element, chord.Chord):
                notes.append(".".join(str(n) for n in element.normalOrder))
                offset_dif = float(element.offset - prev_offset)

                durations.append(str(element.quarterLength))

                offsets.append(round(offset_dif, 3))
                prev_offset = element.offset

    return [notes, offsets, durations]

# %%
data = data_extractor("*.mid")
note_data = data[0]
offset_data = data[1]
duration_data = data[2]

unique_note_number = len(list(set(note_data)))
unique_notes = sorted(list(set(note_data)))
unique_offset_number = len(list(set(offset_data)))
unique_offsets = sorted(list(set(offset_data)))
unique_duration_number = len(list(set(duration_data)))
unique_durations = sorted(list(set(duration_data)))
# Out:
# C#6
# C6
# B-5
# C6
# B-5
# G#5
# G5
# G#5
# G5
# F5
# E5
# C#5
# C5
# B-4
# C5
# B-4
# G#4
# G4
# G#4
# G4
# F4
# E4
# C#5
# C5
# B-4
# C5
# B-4
# G#4
# G4
# G#4
# G4
# F4
# E4
# F4
# E4
# C#4
# C4
# C#4
# C4
# B3
# B-3
# C4
# B-3
# G#3
# G3
# G#3
# G3
# F3
# E3
# F3
# E3
# C#3
# C3
# C2
# C#3
# C#2
# C3
# C2
# B2
# B1
# C3
# C2
# C#3
# C#2
# C3
# C2
# B2
# B1
# C3
# C2
# C#3
# C#2
# C3
# C2
# B2
# B1
# C3
# C2
# C#3
# C#2
# C3
# C2
# B2
# B1
# C3
# C2
# C#3
# C#2
# C3
# C2
# B2
# B1
# B-2
# B-1
# C3
# C2
# B-2
# B-1
# A2
# A1
# B-2
# B-1
# C3
# C2
# B-2
# B-1
# A2
# A1
# B-2
# B-1
# C3
# C2
# B-2
# B-1
# A2
# A1
# B-2
# B-1
# C3
# C2
# B-2
# B-1
# A2
# A1
# B-2
# B-1
# C3
# C2
# B-2
# B-1
# A2
# A1
# B-2
# B-1
# C3
# C2
# B-2
# B-1
# A2
# A1
# B-2
# B-1
# G2
# G1
# G#2
# G#1
# B-2
# B-1
# C3
# C2
# B-2
# B-1
# G#2
# G#1
# G2
# G1
# F1
# C3
# F3
# G#3
# C4
# C#4
# C4
# B-3
# G#3
# B-3
# G#3
# G3
# F3
# G3
# G#3
# F3
# F2
# F1
# C3
# F3
# G#3
# C4
# C#4
# C4
# B-3
# G#3
# B-3
# G#3
# G3
# F3
# G3
# G#3
# F3
# F2
# B-1
# C#3
# F#3
# B-3
# C#4
# E-4
# C#4
# C4
# B-3
# C4
# B-3
# G#3
# F#3
# G#3
# F#3
# F3
# C#2
# E3
# C2
# F3
# G3
# E3
# F3
# C#2
# G3
# G#3
# F3
# G3
# B-1
# G#3
# B-3
# G3
# E3
# C2
# F3
# G3
# E3
# F3
# C3
# F3
# G#3
# C4
# C#4
# C4
# B-3
# G#3
# B-3
# G#3
# G3
# F3
# G3
# G#3
# F3
# C3
# F3
# G#3
# C4
# C#4
# C4
# B-3
# G#3
# B-3
# G#3
# G3
# F3
# G3
# G#3
# F3
# C#3
# F#3
# B-3
# C#4
# E-4
# C#4
# C4
# B-3
# C4
# B-3
# G#3
# F#3
# G#3
# F#3
# F3
# E3
# F3
# G3
# E3
# F3
# G3
# G#3
# F3
# G3
# G#3
# B-3
# G3
# E3
# F3
# G3
# E3
# F3
# C4
# F4
# G#4
# C5
# C4
# F4
# G#4
# C4
# F4
# G#4
# C5
# C4
# F4
# G#4
# B3
# D4
# G#4
# B4
# B3
# D4
# G#4
# B4
# B3
# E4
# G4
# C5
# C4
# E4
# G4
# C4
# E4
# G4
# C5
# C4
# E4
# G4
# C4
# E4
# G4
# C5
# C4
# E4
# G4
# C4
# E4
# G4
# C5
# C4
# E4
# G4
# C5
# C4
# E4
# G4
# C5
# C4
# F4
# G#4
# F4
# A4
# C5
# F5
# F4
# A4
# C5
# F4
# A4
# C5
# F5
# F4
# A4
# C5
# F4
# A4
# C5
# F5
# F4
# A4
# C5
# F5
# F5
# F5
# F5
# C4
# F4
# G#4
# C5
# C4
# F4
# G#4
# C5
# C4
# G4
# B-4
# C5
# C4
# E4
# G4
# F3
# C4
# G#3
# F3
# C3
# G#3
# F3
# C3
# G#2
# F3
# C3
# G#2
# F2
# C3
# G#2
# F2
# C2
# F2
# G#2
# C3
# B2
# C3
# B2
# C3
# B2
# C3
# G2
# C3
# E2
# C3
# G2
# C3
# C2
# E2
# G2
# C3
# E2
# G2
# C3
# E3
# G2
# C3
# E3
# G3
# C3
# E3
# G3
# C4
# F3
# G#3
# C4
# F4
# E4
# F4
# E4
# F4
# E4
# F4
# C4
# F4
# G#3
# F4
# C4
# F4
# F3
# A3
# C4
# F4
# A3
# C4
# F4
# A4
# C4
# F4
# A4
# C5
# F4
# A4
# C5
# F5
# A4
# F5
# E5
# F5
# A4
# F5
# A4
# F5
# A4
# F5
# B-4
# F5
# C5
# F5
# C#5
# F5
# C4
# F4
# G#4
# C5
# B4
# C5
# B4
# C5
# C4
# E4
# G4
# C5
# C4
# G4
# B-4
# C5
# F3
# C5
# F5
# G#5
# C6
# C#6
# C6
# B-5
# G#5
# B-5
# G#5
# G5
# F5
# G5
# G#5
# F5
# F3
# C5
# F5
# G#5
# C6
# C#6
# C6
# B-5
# G#5
# B-5
# G#5
# G5
# F5
# G5
# G#5
# F5
# G2
# F5
# B5
# D6
# F6
# G6
# F6
# E-6
# D6
# E-6
# D6
# C6
# B5
# C6
# D6
# B5
# G2
# F5
# B5
# D6
# F6
# G6
# F6
# E-6
# D6
# E-6
# D6
# C6
# B5
# C6
# D6
# B5
# C3
# G5
# C6
# E-6
# G6
# G#6
# G6
# F6
# E-6
# F6
# E-6
# D6
# C6
# D6
# E-6
# C6
# C3
# G5
# C6
# G4
# E-6
# E-4
# G6
# C5
# G#6
# G4
# G6
# C5
# F6
# G4
# E-6
# E-5
# F6
# C5
# E-6
# E-5
# D6
# C5
# C6
# G5
# D6
# E-5
# E-6
# G5
# C6
# E-5
# C#6
# E-6
# C#6
# E-6
# C#6
# C6
# C#6
# B5
# C6
# B5
# C6
# D6
# C6
# C#6
# E-6
# C#6
# E-6
# C#6
# C6
# C#6
# B5
# C6
# B5
# C6
# D6
# C6
# C#6
# E-6
# C#6
# E-6
# C#6
# C6
# D6
# B5
# C6
# B5
# G#5
# B-5
# G#5
# G5
# G#5
# G5
# F#5
# G5
# F#5
# F5
# G5
# F5
# E-5
# F5
# E-5
# F#4
# E-5
# F5
# E-5
# G#4
# D5
# E-5
# D5
# E-4
# C5
# D5
# C5
# D4
# B4
# C5
# B4
# G#4
# G#5
# G#4
# G#5
# G#4
# G#5
# G#4
# G#4
# G#5
# G5
# F5
# E-5
# D5
# C5
# G#5
# G#6
# G#5
# G#6
# G#5
# G#6
# G#5
# G#5
# G#6
# G6
# F6
# E-6
# D6
# C6
# G#4
# G#5
# G#4
# G#5
# G#4
# G#5
# G#4
# G#5
# G#4
# G#5
# G#6
# G#5
# G#6
# G6
# G5
# G6
# F#6
# F#5
# F#6
# F6
# F5
# F6
# E-6
# E-6
# E-3
# E-6
# E-6
# D3
# D6
# D6
# C3
# G2
# C6
# C6
# B2
# B5
# B5
# G4
# C5
# E-5
# G5
# G#5
# G3
# G5
# C4
# F5
# E-4
# E-5
# G4
# F5
# G#4
# E-5
# G4
# D5
# F4
# C5
# E-4
# B-4
# D4
# G#4
# C4
# G4
# B-3
# F4
# G#3
# E-4
# G3
# D4
# F3
# C4
# E-3
# B3
# D3
# E-3
# F3
# E-3
# D3
# C3
# B2
# G#2
# G2
# F2
# E-2
# D2
# G5
# C6
# E-6
# G6
# G#6
# G4
# G6
# C5
# F6
# E-5
# E-6
# G5
# F6
# G#5
# E-6
# G5
# D6
# F5
# C6
# E-5
# B-5
# D5
# G#5
# C5
# G5
# B-4
# F5
# G#4
# E-5
# G4
# D5
# F4
# C5
# E-4
# B4
# D4
# E-4
# F4
# E-4
# D4
# C4
# B3
# G#3
# G3
# F3
# E-3
# D3
# C3
# D3
# E-3
# F3
# G3
# A3
# B3
# C4
# D4
# C4
# B3
# G#3
# G3
# F3
# E-3
# D3
# C3
# D3
# E-3
# F3
# G3
# A3
# B3
# C4
# D4
# C4
# B3
# G#3
# G3
# F3
# E-3
# D3
# C3
# D3
# E-3
# F3
# G3
# A3
# B3
# C4
# B-3
# G#3
# G3
# F3
# E3
# D3
# C3
# B-2
# G#2
# B-2
# C3
# D3
# E3
# F3
# G3
# G#3
# G3
# F3
# E3
# D3
# C3
# B-2
# G#2
# G2
# A3
# C4
# E-4
# F#4
# A4
# C5
# E-5
# F#5
# A5
# C6
# E-6
# F#6
# E-6
# C6
# A5
# F#5
# E-5
# C5
# A4
# F#4
# E-4
# C4
# A3
# F#3
# E-3
# C3
# A2
# F#2
# E-2
# C2
# A1
# F#1
# A1
# C2
# E-2
# F#1
# A1
# C2
# E-2
# F#1
# A1
# C2
# E-2
# F#1
# A1
# C2
# E-2
# F1
# A3
# C4
# E-4
# F#4
# G#4
# F#4
# F4
# E-4
# F4
# E-4
# C#4
# C4
# C#4
# E-4
# C4
# F2
# F1
# A3
# C4
# E-4
# F#4
# G#4
# F#4
# F4
# E-4
# F4
# E-4
# C#4
# C4
# C#4
# E-4
# C4
# F2
# F1
# A3
# C4
# E-4
# F#4
# G#4
# F#4
# A3
# F4
# B-3
# E-4
# C4
# C#4
# E-4
# C4
# F4
# B-3
# F#4
# A3
# G#4
# F#4
# A3
# F4
# B-3
# E-4
# C4
# C#4
# E-4
# C4
# F4
# B-3
# F#4
# A3
# G#4
# F#4
# A3
# F4
# B-3
# E-4
# C4
# C#4
# C4
# B-3
# A3
# F#3
# F3
# E-3
# C#3
# F4
# F3
# B-4
# B-3
# C#5
# F3
# F5
# B-3
# F#5
# F3
# F5
# B-3
# E-5
# F3
# C#5
# B-3
# C#3
# E-5
# F3
# C#5
# B-3
# C5
# F3
# B-4
# B-3
# C5
# F3
# C#5
# B-3
# B-4
# F3
# C#3
# F4
# F3
# B-4
# B-3
# C#5
# F3
# F5
# B-3
# F#5
# F3
# F5
# B-3
# E-5
# F3
# C#5
# B-3
# C#3
# E-5
# F3
# C#5
# B-3
# C5
# F3
# B-4
# B-3
# C5
# F3
# C#5
# B-3
# B-4
# F3
# E-3
# F#4
# F#3
# B4
# B3
# E-5
# F#3
# F#5
# B3
# G#5
# F#3
# F#5
# B3
# F5
# F#3
# E-5
# B3
# E-3
# F5
# F#3
# E-5
# B3
# C#5
# F#3
# B4
# B3
# C#5
# F#3
# E-5
# B3
# B4
# F#3
# B-4
# F3
# C5
# B-3
# B-4
# C#4
# A4
# B-3
# B-4
# C#4
# C5
# B-3
# C#5
# C#4
# B-4
# B-3
# A4
# E-3
# B-4
# F3
# A4
# C4
# G4
# F3
# A4
# C4
# B-4
# F3
# C5
# C4
# A4
# F3
# B-4
# C#3
# F4
# B-4
# C#5
# F5
# B-3
# F#5
# C#4
# F5
# F4
# E-5
# C#4
# C#5
# A3
# E-5
# C#4
# C#5
# F4
# C5
# C#4
# B-3
# C5
# C#4
# C#5
# F4
# B-4
# C#4
# A5
# C#3
# F4
# B-4
# C#5
# B-3
# F#5
# C#4
# F5
# F4
# E-5
# C#4
# C#5
# A3
# E-5
# C#4
# C#5
# F4
# C5
# C#4
# B-3
# C5
# C#4
# C#5
# F4
# B-4
# C#4
# E-3
# F#5
# B5
# E-4
# E-6
# F#6
# E-4
# G#6
# F#6
# E-4
# F6
# E-6
# E-4
# F6
# E-6
# E-4
# C#6
# B5
# E-4
# C#6
# B5
# E-4
# B-5
# A5
# F4
# C6
# E-6
# F4
# C#6
# C6
# F4
# C#6
# C6
# F4
# B-5
# A5
# F4
# B-5
# A4
# A5
# F4
# F#5
# A4
# F5
# F3
# E-5
# F4
# C#5
# F3
# C5
# F4
# B-4
# B-2
# F5
# F4
# F4
# F5
# F4
# F5
# F4
# F#5
# E4
# E4
# F#5
# E4
# F#5
# E4
# F5
# F4
# F4
# F5
# F4
# F5
# F4
# C5
# F4
# C#5
# F4
# E-5
# F4
# C#5
# F4
# F4
# F4
# F4
# F4
# E4
# E4
# E4
# E4
# F4
# F4
# F4
# F4
# F4
# F4
# F4
# F4
# C5
# C4
# C4
# C5
# C4
# C5
# C4
# B4
# D4
# D4
# B4
# D4
# B4
# D4
# C5
# C4
# C4
# C5
# C4
# C5
# C4
# G4
# C4
# G#4
# C4
# B-4
# C4
# G#4
# C4
# C4
# C4
# C4
# C4
# D4
# D4
# D4
# D4
# C4
# C4
# C4
# C4
# C4
# C4
# C4
# C4
# F4
# G#4
# C5
# C#5
# C3
# C5
# F3
# B-4
# G#3
# G#4
# C4
# B-4
# C#4
# G#4
# C4
# G4
# B-3
# F4
# G#3
# G4
# B-3
# G#4
# C4
# F4
# G#3
# F#4
# B-3
# C#4
# C4
# F#4
# B-3
# B-4
# G#3
# C#5
# F#3
# E-5
# C#3
# C#5
# F#3
# C5
# B-3
# B-4
# C#4
# C5
# E-4
# B-4
# C#4
# G#4
# C4
# F#4
# B-3
# G#4
# C4
# B-4
# C#4
# F#4
# B-3
# A4
# C4
# E-4
# C#4
# A4
# C4
# C5
# B-3
# E-5
# A3
# F5
# E-3
# E-5
# A3
# C#5
# C4
# C5
# E-4
# C#5
# F4
# C5
# E-4
# B-4
# C#4
# A4
# C4
# B-4
# C#4
# C5
# E-4
# A4
# C4
# B-4
# C#4
# F4
# F3
# B-4
# B-3
# C#5
# C#4
# F5
# F4
# F#5
# F#4
# F5
# F4
# E-5
# E-4
# C#5
# C#4
# C5
# C4
# B-4
# B-3
# G#4
# G#3
# F#4
# F#3
# F4
# F3
# E-4
# E-3
# C#4
# C#3
# C4
# C3
# B-3
# B-2
# G#3
# G#2
# F#3
# F#2
# F3
# F2
# E-3
# E-2
# C#3
# C#2
# C3
# C2
# B-2
# B-1
# C3
# C2
# C#3
# C#2
# B-2
# C2
# B-2
# B-1
# B1
# C2
# E2
# C2
# F2
# C2
# G2
# C2
# G#2
# C2
# B-2
# C2
# G#2
# C2
# G2
# C2
# F2
# C2
# E2
# C2
# F2
# C2
# G2
# C2
# G#2
# C2
# A2
# C2
# B-2
# C2
# B2
# C2
# C3
# C#3
# F#3
# B-3
# C#4
# B-2
# C#3
# F#3
# B-3
# C#4
# F#4
# B-4
# C#5
# B-3
# C#4
# F#4
# B-4
# C#5
# F#5
# B-5
# C#6
# E3
# G3
# B-3
# E4
# C3
# G3
# B-3
# C4
# E4
# G4
# B-4
# E5
# C4
# G4
# B-4
# C5
# E5
# G5
# B-5
# E6
# C#2
# C#3
# E3
# G3
# B-3
# C#4
# E4
# G4
# E2
# E3
# G3
# B-3
# C#4
# E4
# G4
# B-4
# G2
# G3
# B-3
# C#4
# E4
# G4
# B-4
# C#5
# B-2
# B-3
# C#4
# E4
# G4
# B-4
# C#5
# E5
# C#3
# E3
# G3
# B-3
# C#4
# E4
# G4
# B-4
# C#5
# E5
# G5
# B-5
# C#6
# E6
# G6
# B-6
# G6
# E6
# C#6
# B-5
# G5
# E5
# C#5
# B-4
# G4
# E4
# C#4
# B-3
# G3
# E3
# C#3
# B-2
# G2
# E2
# C#2
# B-1
# G1
# G1
# C2
# C2
# C2
# C2
# C2
# C2
# C2
# C3
# F3
# G#3
# C4
# C#4
# C4
# B-3
# G#3
# B-3
# G#3
# G3
# F3
# G3
# G#3
# F3
# C3
# F3
# G#3
# C4
# C#4
# C4
# B-3
# G#3
# B-3
# G#3
# G3
# F3
# G3
# G#3
# F3
# C#3
# F#3
# B-3
# C#4
# E-4
# C#4
# C4
# B-3
# C4
# B-3
# G#3
# F#3
# G#3
# F#3
# F3
# E3
# F3
# G3
# E3
# F3
# G3
# G#3
# F3
# G3
# G#3
# B-3
# G3
# E3
# F3
# G3
# E3
# F3
# C3
# F3
# G#3
# C4
# C#4
# E4
# C4
# B-3
# F4
# G#3
# B-3
# G4
# G#3
# G3
# G#4
# F3
# G3
# F4
# G#3
# F3
# G#3
# C3
# F3
# G#3
# C4
# C#4
# C4
# B-3
# G#3
# B-3
# G#3
# G3
# F3
# G3
# G#3
# F3
# B-3
# C#3
# F#3
# B-3
# C#4
# E-4
# C#4
# C4
# B-3
# C4
# B-3
# G#3
# F#3
# G#3
# F#3
# F3
# E3
# F3
# G3
# G#3
# B-3
# G#3
# G3
# F3
# E3
# F3
# E3
# C#3
# C3
# B-2
# G#2
# G2
# F2
# C4
# F4
# G#4
# C5
# C4
# F4
# G#4
# C4
# F4
# G#4
# C5
# C4
# F4
# G#4
# B3
# D4
# G#4
# B4
# B3
# D4
# G#4
# B4
# B3
# E4
# G4
# C5
# C4
# E4
# G4
# C4
# E4
# G4
# C5
# C4
# E4
# G4
# C4
# E4
# G4
# C5
# C4
# E4
# G4
# C4
# E4
# G4
# C5
# C4
# E4
# G4
# C5
# C4
# E4
# G4
# C5
# C4
# F4
# G#4
# F4
# A4
# C5
# F5
# F4
# A4
# C5
# F4
# A4
# C5
# F5
# F4
# A4
# C5
# F4
# A4
# C5
# F5
# F4
# A4
# C5
# F5
# F5
# F5
# F5
# C4
# F4
# G#4
# C5
# C4
# F4
# G#4
# C5
# C4
# G4
# B-4
# C5
# C4
# E4
# F3
# G4
# C4
# G#3
# F3
# C3
# G#3
# F3
# C3
# G#2
# F3
# C3
# G#2
# F2
# C3
# G#2
# F2
# C2
# F2
# G#2
# C3
# B2
# C3
# B2
# C3
# B2
# C3
# G2
# C3
# E2
# C3
# G2
# C3
# C2
# E2
# G2
# C3
# E2
# G2
# C3
# E3
# G2
# C3
# E3
# G3
# C3
# E3
# G3
# C4
# F3
# G#3
# C4
# F4
# E4
# F4
# E4
# F4
# E4
# F4
# C4
# F4
# G#3
# F4
# C4
# F4
# F3
# A3
# C4
# F4
# A3
# C4
# F4
# A4
# C4
# F4
# A4
# C5
# F4
# A4
# C5
# F5
# A4
# F5
# E5
# F5
# A4
# F5
# A4
# F5
# A4
# F5
# B-4
# F5
# C5
# F5
# C#5
# F5
# C4
# F4
# G#4
# C5
# B4
# C5
# B4
# C5
# C4
# E4
# G4
# C5
# C4
# G4
# B-4
# C5
# F3
# C5
# F5
# G#5
# C6
# C#6
# C6
# B-5
# G#5
# B-5
# G#5
# G5
# F5
# F3
# G5
# G#5
# F5
# C5
# F5
# G#5
# C6
# C#6
# C6
# B-5
# G#5
# B-5
# G#5
# G5
# F5
# G#2
# G5
# G#5
# F5
# F#5
# C6
# E-6
# F#6
# G#6
# F#6
# F6
# E-6
# F6
# E-6
# C#6
# C6
# G#2
# C#6
# E-6
# C6
# F#5
# C6
# E-6
# F#6
# G#6
# F#6
# F6
# E-6
# F6
# E-6
# C#6
# C6
# C#3
# B-5
# G#5
# F#5
# F5
# G#5
# C#6
# F6
# G#6
# B-6
# G#6
# F#6
# F6
# F#6
# F6
# E-6
# C#6
# C#3
# E-6
# F6
# C#6
# G#4
# G#5
# C#6
# C#5
# F6
# G#6
# F5
# B-6
# G#6
# G#5
# F#6
# F6
# C#6
# F#6
# G#6
# C#6
# F#6
# F6
# F#6
# G#6
# F6
# F#6
# G#6
# F#6
# G#6
# F#6
# F6
# F#6
# E6
# F6
# E6
# F6
# G6
# F6
# F#6
# G#6
# F#6
# G#6
# F#6
# F6
# F#6
# E6
# F6
# E6
# F6
# G6
# F6
# F#6
# G#6
# F#6
# G#6
# F#6
# F6
# G6
# E6
# F6
# E6
# C#6
# E-6
# C#6
# C6
# C#6
# C6
# B5
# C6
# B5
# B-5
# C6
# B-5
# B4
# G#5
# B-5
# G#5
# D5
# G#5
# B-5
# G#5
# G#4
# G5
# G#5
# G5
# G4
# F5
# G5
# F5
# E5
# F5
# E5
# C#4
# C#5
# C#4
# C#5
# C#4
# C#5
# C#4
# C#4
# C#5
# C5
# B-4
# G#4
# G4
# F4
# C#5
# C#6
# C#5
# C#6
# C#5
# C#6
# C#5
# C#5
# C#6
# C6
# B-5
# G#5
# G5
# F5
# C#4
# C#5
# C#4
# C#5
# C#4
# C#5
# C#4
# C#5
# C#4
# C#5
# C#6
# C#5
# C#6
# C6
# C5
# C6
# B5
# B4
# B5
# B-5
# B-4
# B-5
# B1
# G#2
# G#5
# G#5
# F#2
# G#5
# G#5
# C2
# F2
# G5
# G5
# E2
# F5
# F5
# E5
# E5
# C4
# C3
# F4
# F3
# G#4
# G#3
# C5
# C4
# C#5
# C#4
# C5
# C4
# B-4
# B-3
# G#4
# G#3
# B-4
# G3
# G#4
# F3
# G4
# E-3
# F4
# C#3
# E-4
# C3
# C#4
# B-2
# C4
# G#2
# B-3
# G2
# G#3
# G#2
# F#3
# B-2
# F3
# G#2
# E3
# G2
# F2
# E2
# D2
# C2
# B-1
# G#1
# G1
# C5
# C4
# F5
# F4
# G#5
# G#4
# C6
# C5
# C#6
# C#5
# C6
# C5
# B-5
# B-4
# G#5
# G#4
# B-5
# G4
# G#5
# F4
# G5
# E-4
# F5
# C#4
# E-5
# C4
# C#5
# B-3
# C5
# G#3
# B-4
# G3
# G#4
# G#3
# G4
# B-3
# F4
# G#3
# E4
# G3
# F3
# E3
# D3
# C3
# B-2
# G#2
# G2
# F2
# G2
# G#2
# B-2
# C3
# D3
# E3
# F3
# G3
# F3
# E3
# D3
# C3
# B-2
# G#2
# G2
# F2
# G2
# G#2
# B-2
# C3
# D3
# E3
# F3
# G3
# F3
# E3
# D3
# C3
# B-2
# G#2
# G2
# F2
# E2
# D2
# C2
# B-1
# G#1
# G1
# F1
# G1
# G#1
# B-1
# C2
# D2
# E2
# F2
# G2
# A3
# C4
# E-4
# F#4
# A4
# C5
# E-5
# F#5
# A5
# C6
# E-6
# F#6
# E-6
# C6
# A5
# F#5
# E-5
# C5
# A4
# A3
# F#4
# F#3
# E-4
# E-3
# C4
# C3
# A2
# F#2
# E-2
# C2
# A1
# F#1
# E-2
# C2
# A1
# F#1
# E-2
# C2
# A1
# F#1
# E-2
# C2
# A1
# F#1
# E-2
# C2
# A1
# F1
# A3
# C4
# E-4
# F#4
# G#4
# F#4
# F4
# E-4
# F4
# E-4
# C#4
# F2
# C4
# F1
# C#4
# E-4
# C4
# A3
# C4
# E-4
# F#4
# G#4
# F#4
# F4
# E-4
# F4
# E-4
# C#4
# F2
# C4
# F1
# C#4
# E-4
# C4
# A3
# C4
# A3
# E-4
# B-3
# F#4
# C4
# G#4
# C#4
# F#4
# C4
# F4
# B-3
# E-4
# A3
# E-4
# A3
# F4
# B-3
# F#4
# C4
# G#4
# C#4
# F#4
# C4
# F4
# B-3
# E-4
# A3
# E-4
# A3
# F4
# B-3
# F#4
# C4
# G#4
# C#4
# F#4
# C4
# F4
# B-3
# E-4
# A3
# F#3
# F3
# E-3
# C#3
# F3
# B-3
# F3
# B-3
# F4
# F3
# B-4
# B-3
# C#5
# F3
# F5
# B-3
# C#3
# F#5
# F3
# F5
# B-3
# E-5
# F3
# C#5
# B-3
# E-5
# F3
# C#5
# B-3
# C5
# F3
# B-4
# C#3
# C5
# F3
# C#5
# B-3
# B-4
# F3
# B-3
# F4
# F3
# B-4
# B-3
# C#5
# F3
# F5
# B-3
# C#3
# F#5
# F3
# F5
# B-3
# E-5
# F3
# C#5
# B-3
# E-5
# F3
# C#5
# B-3
# C5
# F3
# B-4
# E-3
# C5
# F#3
# C#5
# B3
# B-4
# F#3
# B3
# F#4
# F#3
# B4
# B3
# E-5
# F#3
# F#5
# B3
# E-3
# G#5
# F#3
# F#5
# B3
# F5
# F#3
# E-5
# B3
# F5
# F#3
# E-5
# B3
# C#5
# F#3
# B4
# F3
# C#5
# B-3
# E-5
# C#4
# B4
# B-3
# B-4
# C#4
# C5
# B-3
# B-4
# C#4
# A4
# B-3
# B-4
# E-3
# C5
# F3
# C#5
# C4
# B-4
# F3
# A4
# C4
# B-4
# F3
# A4
# C4
# G4
# F3
# A4
# C#3
# B-4
# F4
# C5
# A4
# B-4
# B-3
# C#4
# B-4
# F4
# C#5
# C#4
# F5
# A3
# F#5
# C#4
# F5
# F4
# E-5
# C#4
# C#5
# B-3
# E-5
# C#4
# C#5
# F4
# C5
# C#4
# C#3
# C5
# F4
# C#5
# B-4
# A5
# B-3
# C#4
# B-4
# F4
# C#5
# C#4
# A3
# F#5
# C#4
# F5
# F4
# E-5
# C#4
# C#5
# B-3
# E-5
# C#4
# C#5
# F4
# C5
# C#4
# E-3
# C5
# C#5
# E-4
# B-4
# E-4
# F#5
# B5
# E-4
# E-6
# F#6
# E-4
# G#6
# F#6
# E-4
# F6
# E-6
# E-4
# F6
# E-6
# E-4
# C#6
# B5
# F4
# C#6
# B5
# F4
# B-5
# A5
# F4
# C6
# E-6
# F4
# C#6
# C6
# F4
# C#6
# A4
# C6
# F4
# B-5
# A4
# A5
# F3
# B-5
# F4
# A5
# F3
# F#5
# F4
# F5
# B-2
# E-5
# C#5
# C5
# F4
# B-4
# F4
# F5
# F4
# F4
# F5
# E4
# F5
# E4
# F#5
# E4
# E4
# F#5
# F4
# F#5
# F4
# F5
# F4
# F4
# F5
# F4
# F5
# F4
# C5
# F4
# C#5
# F4
# E-5
# F4
# C#5
# F4
# F4
# F4
# E4
# E4
# E4
# E4
# F4
# F4
# F4
# F4
# F4
# F4
# F4
# F4
# C4
# C4
# C5
# C4
# C4
# C5
# D4
# C5
# D4
# B4
# D4
# D4
# B4
# C4
# B4
# C4
# C5
# C4
# C4
# C5
# C4
# C5
# C4
# G4
# C4
# G#4
# C4
# B-4
# C4
# G#4
# C4
# C4
# C4
# D4
# D4
# D4
# D4
# C4
# C4
# C4
# C4
# C4
# C4
# C4
# C4
# C3
# F4
# F3
# G#4
# G#3
# C5
# C4
# C#5
# C#4
# C5
# C4
# B-4
# B-3
# G#4
# G#3
# B-4
# B-3
# G#4
# C4
# G4
# G#3
# F4
# B-3
# G4
# C4
# G#4
# B-3
# F4
# G#3
# F#4
# F#3
# C#4
# C#3
# F#4
# F#3
# B-4
# B-3
# C#5
# C#4
# E-5
# E-4
# C#5
# C#4
# C5
# C4
# B-4
# B-3
# C5
# C4
# B-4
# C#4
# G#4
# B-3
# F#4
# C4
# G#4
# C#4
# B-4
# C4
# F#4
# B-3
# A4
# A3
# E-4
# E-3
# A4
# A3
# C5
# C4
# E-5
# E-4
# F5
# F4
# E-5
# E-4
# C#5
# C#4
# C5
# C4
# C#5
# C#4
# C5
# E-4
# B-4
# C4
# A4
# C#4
# B-4
# F3
# C5
# B-3
# A4
# C#4
# B-4
# F4
# F4
# F#4
# B-4
# F4
# C#5
# E-4
# F5
# C#4
# F#5
# C4
# F5
# B-3
# E-5
# G#3
# C#5
# F#3
# C5
# F3
# B-4
# E-3
# G#4
# C#3
# F#4
# C3
# F4
# B-2
# E-4
# G#2
# C#4
# F#2
# C4
# F2
# B-3
# E-2
# G#3
# C#2
# F#3
# C2
# F3
# B-1
# E-3
# C2
# C#3
# C#2
# C3
# C2
# B-2
# B-1
# C3
# C#3
# B1
# B-2
# B-2
# C2
# E2
# C2
# F2
# C2
# G2
# C2
# G#2
# C2
# B-2
# C2
# G#2
# C2
# G2
# C2
# F2
# C2
# E2
# C2
# F2
# C2
# G2
# C2
# G#2
# C2
# A2
# C2
# B-2
# C2
# B2
# C2
# C3
# C#3
# F#3
# B-3
# C#4
# B-2
# C#3
# F#3
# B-3
# C#4
# B-3
# F#4
# C#4
# B-4
# F#4
# C#5
# B-4
# C#5
# F#5
# B-5
# C#6
# E3
# G3
# B-3
# C3
# G3
# B-3
# E4
# C4
# E4
# C4
# G4
# G4
# B-4
# B-4
# E5
# C5
# E5
# G5
# B-5
# E6
# C#2
# C#3
# E3
# G3
# B-3
# C#4
# E4
# G4
# E2
# E3
# G3
# B-3
# C#4
# E4
# G4
# B-4
# G2
# G3
# B-3
# C#4
# E4
# G4
# B-4
# C#5
# B-2
# B-3
# C#4
# E4
# G4
# B-4
# C#5
# E5
# C#3
# E3
# G3
# B-3
# C#4
# E4
# G4
# B-4
# C#5
# E5
# G5
# B-5
# C#6
# E6
# G6
# B-6
# G6
# E6
# C#6
# B-5
# G5
# E5
# C#5
# B-4
# G4
# E4
# B-3
# C#4
# G3
# E3
# C#3
# B-2
# G2
# E2
# C#2
# B-1
# G1
# G1
# C2
# C2
# C2
# C2
# C2
# C2
# C2
# C3
# F3
# G#3
# C4
# C#4
# C4
# B-3
# G#3
# B-3
# G#3
# G3
# F3
# G3
# G#3
# F3
# C3
# F3
# G#3
# C4
# C#4
# C4
# B-3
# G#3
# B-3
# G#3
# G3
# F3
# G3
# G#3
# F3
# C#3
# F#3
# B-3
# C#4
# E-4
# C#4
# C4
# B-3
# C4
# B-3
# G#3
# F#3
# G#3
# F#3
# F3
# E3
# F3
# G3
# E3
# F3
# G3
# G#3
# F3
# G3
# G#3
# B-3
# G3
# E3
# F3
# C3
# G3
# F3
# E3
# G#3
# F3
# C4
# C#4
# C4
# B-3
# G#3
# B-3
# E4
# G#3
# G3
# F4
# F3
# G3
# G4
# G#3
# F3
# G#4
# G#3
# C3
# F4
# F3
# G#3
# C4
# C#4
# C4
# B-3
# G#3
# B-3
# G#3
# G3
# F3
# G3
# G#3
# F3
# B-3
# C#3
# F#3
# B-3
# C#4
# E-4
# C#4
# C4
# B-3
# C4
# B-3
# G#3
# F#3
# G#3
# F#3
# F3
# E3
# F3
# G3
# G#3
# B-3
# G#3
# G3
# F3
# E3
# F3
# E3
# C#3
# C3
# B-2
# G#2
# G2
# F2
# C4
# F4
# G#4
# C5
# C4
# F4
# G#4
# C4
# F4
# G#4
# C5
# C4
# F4
# G#4
# B3
# D4
# G#4
# B4
# B3
# D4
# G#4
# B4
# B3
# E4
# G4
# C5
# C4
# E4
# G4
# C4
# E4
# G4
# C5
# C4
# E4
# G4
# C4
# E4
# G4
# C5
# C4
# E4
# G4
# C4
# E4
# G4
# C5
# C4
# E4
# G4
# C5
# C4
# E4
# G4
# C5
# C4
# F4
# G#4
# F4
# A4
# C5
# F5
# F4
# A4
# C5
# F4
# A4
# C5
# F5
# F4
# A4
# C5
# F4
# A4
# C5
# F5
# F4
# A4
# C5
# F5
# F5
# F5
# F5
# C4
# F4
# G#4
# C5
# C4
# F4
# G#4
# C5
# C4
# G4
# F3
# B-4
# C4
# C5
# G#3
# C4
# F3
# E4
# C3
# G4
# G#3
# F3
# C3
# G#2
# F3
# C3
# G#2
# F2
# C3
# G#2
# F2
# C2
# F2
# G#2
# C3
# B2
# C3
# B2
# C3
# B2
# C3
# G2
# C3
# E2
# C3
# G2
# C3
# C2
# E2
# G2
# C3
# E2
# G2
# C3
# E3
# G2
# C3
# E3
# G3
# C3
# E3
# G3
# C4
# F3
# G#3
# C4
# F4
# E4
# F4
# E4
# F4
# E4
# F4
# C4
# F4
# G#3
# F4
# C4
# F4
# F3
# A3
# C4
# F4
# A3
# C4
# F4
# A4
# C4
# F4
# A4
# C5
# F4
# A4
# C5
# F5
# A4
# F5
# E5
# F5
# A4
# F5
# A4
# F5
# A4
# F5
# B-4
# F5
# C5
# F5
# C#5
# F5
# C4
# F4
# G#4
# C5
# B4
# C5
# B4
# C5
# C4
# E4
# G4
# C5
# C4
# G4
# B-4
# C5
# F3
# C5
# F5
# G#5
# C6
# C#6
# C6
# B-5
# G#5
# F3
# B-5
# G#5
# G5
# F5
# G5
# G#5
# F5
# C5
# F5
# G#5
# C6
# C#6
# C6
# B-5
# G#5
# G#2
# B-5
# G#5
# G5
# F5
# G5
# G#5
# F5
# F#5
# C6
# E-6
# F#6
# G#6
# F#6
# F6
# E-6
# G#2
# F6
# E-6
# C#6
# C6
# C#6
# E-6
# C6
# F#5
# C6
# E-6
# F#6
# G#6
# F#6
# F6
# E-6
# C#3
# F6
# E-6
# C#6
# C6
# B-5
# G#5
# F#5
# F5
# G#5
# C#6
# F6
# G#6
# B-6
# G#6
# F#6
# F6
# C#3
# F#6
# F6
# E-6
# C#6
# G#4
# E-6
# F6
# C#5
# C#6
# F5
# G#5
# C#6
# G#5
# F6
# G#6
# C#6
# B-6
# G#6
# C#6
# F#6
# F6
# F#6
# G#6
# F#6
# F6
# F#6
# G#6
# F6
# F#6
# G#6
# F#6
# G#6
# F#6
# F6
# F#6
# E6
# F6
# E6
# F6
# G6
# F6
# F#6
# G#6
# F#6
# G#6
# F#6
# F6
# F#6
# E6
# F6
# E6
# F6
# G6
# F6
# F#6
# G#6
# F#6
# G#6
# F#6
# F6
# G6
# E6
# F6
# E6
# C#6
# E-6
# C#6
# C6
# C#6
# C6
# B5
# C6
# B5
# B4
# B-5
# C6
# B-5
# D5
# G#5
# B-5
# G#5
# G#4
# G#5
# B-5
# G#5
# G4
# G5
# G#5
# G5
# F5
# G5
# F5
# E5
# F5
# E5
# C#4
# C#5
# C#4
# C#5
# C#4
# C#5
# C#4
# C#4
# C#5
# C5
# B-4
# G#4
# G4
# F4
# C#5
# C#6
# C#5
# C#6
# C#5
# C#6
# C#5
# C#5
# C#6
# C6
# B-5
# G#5
# G5
# F5
# C#4
# C#5
# C#4
# C#5
# C#4
# C#5
# C#4
# C#5
# C#4
# C#5
# C#6
# C#5
# C#6
# C6
# C5
# C6
# B5
# B4
# B5
# G#2
# B1
# B-5
# B-4
# B-5
# F#2
# G#5
# G#5
# F2
# C2
# G#5
# G#5
# E2
# G5
# G5
# F5
# F5
# E5
# C3
# F3
# E5
# G#3
# C4
# C4
# C#4
# F4
# C4
# G#4
# B-3
# C5
# G#3
# C#5
# G3
# C5
# F3
# B-4
# E-3
# G#4
# C#3
# B-4
# C3
# G#4
# B-2
# G4
# G#2
# F4
# G2
# E-4
# G#2
# C#4
# B-2
# C4
# G#2
# B-3
# G2
# G#3
# F2
# F#3
# E2
# F3
# D2
# E3
# C2
# B-1
# G#1
# G1
# C4
# F4
# G#4
# C5
# C5
# C#5
# F5
# C5
# G#5
# B-4
# C6
# G#4
# C#6
# G4
# C6
# F4
# B-5
# E-4
# G#5
# C#4
# B-5
# C4
# G#5
# B-3
# G5
# G#3
# F5
# G3
# E-5
# G#3
# C#5
# B-3
# C5
# G#3
# B-4
# G3
# G#4
# F3
# G4
# E3
# F4
# D3
# E4
# C3
# B-2
# G#2
# G2
# F2
# G2
# G#2
# B-2
# C3
# D3
# E3
# F3
# G3
# F3
# E3
# D3
# C3
# B-2
# G#2
# G2
# F2
# G2
# G#2
# B-2
# C3
# D3
# E3
# F3
# G3
# F3
# E3
# D3
# C3
# B-2
# G#2
# G2
# F2
# G4
# G#4
# B-4
# C5
# D5
# E5
# F5
# G5
# F5
# E5
# C#5
# C5
# B-4
# G#4
# G4
# F4
# G4
# G#4
# B-4
# C5
# D5
# E5
# F5
# G5
# F5
# E5
# C#5
# C5
# B-4
# G#4
# G4
# F4
# G4
# G#4
# B-4
# C5
# D5
# E5
# F5
# G5
# F#5
# G5
# F#5
# G5
# F#5
# G5
# F#5
# G5
# F#5
# G5
# F#5
# G5
# F#5
# G5
# F#5
# G5
# F5
# E5
# C#5
# C5
# B-4
# G#4
# G4
# C2
# C2
# C2
# F2
# F2
# F2
# C2
# C2
# C2
# F2
# F2
# F2
# G1
# G2
# G1
# G1
# C2
# C4
# E4
# C2
# C2
# C2
# F2
# F2
# F2
# C2
# C2
# C2
# F2
# F2
# F2
# G1
# G2
# G1
# G1
# C2
# G2
# C4
# G4
# E-2
# E-2
# E-2
# G#2
# G#2
# G#2
# E-2
# E-2
# E-2
# G#2
# G#2
# G#2
# F1
# F1
# F1
# B-2
# B-2
# B-2
# C2
# C3
# C2
# C2
# G2
# F4
# G4
# E-2
# E-2
# E-2
# G#2
# G#2
# G#2
# E-2
# E-2
# E-2
# G#2
# G#2
# G#2
# F1
# F1
# F1
# B-2
# B-2
# B-2
# C2
# C3
# C2
# C2
# F2
# G#2
# C3
# F3
# F4
# F2
# G#2
# C3
# F3
# C4
# F2
# F4
# G#2
# G#4
# C3
# C5
# F3
# C#5
# C5
# B-4
# G#4
# F2
# G#2
# C3
# F3
# B-4
# F2
# G#4
# G#2
# G4
# C3
# F4
# F3
# G4
# G#4
# F4
# G#4
# F2
# G#2
# C3
# F3
# C4
# F2
# F4
# G#2
# G#4
# C3
# C5
# F3
# C#5
# C5
# B-4
# G#4
# B-4
# B-2
# G#4
# C#3
# G4
# F#3
# F4
# B-3
# G4
# G#4
# F4
# F#4
# B-2
# C#3
# F#3
# B-3
# C#4
# B-2
# F#4
# C#3
# B-4
# F#3
# C#5
# B-3
# E-5
# C#5
# C5
# B-4
# C5
# C3
# B-4
# G3
# G#4
# B-3
# F#4
# C4
# G#4
# F#4
# F4
# E4
# C3
# G3
# B-3
# C4
# F4
# C3
# G4
# G3
# G#4
# B-3
# B-4
# C4
# G#4
# G4
# F4
# E4
# F4
# F3
# G4
# G#3
# G#4
# C4
# B-4
# F4
# C5
# D5
# E5
# F5
# F3
# G#3
# C4
# F4
# C5
# F3
# F5
# G#3
# G#5
# C4
# C6
# F4
# C#6
# C6
# B-5
# G#5
# F3
# G#3
# C4
# F4
# B-5
# F3
# G#5
# G#3
# G5
# C4
# F5
# F4
# G5
# G#5
# F5
# G#5
# F3
# G#3
# C4
# F4
# C5
# F3
# F5
# G#3
# G#5
# C4
# C6
# F4
# C#6
# C6
# B-5
# G#5
# B-5
# B-3
# G#5
# C#4
# G5
# F#4
# F5
# B-4
# G5
# G#5
# F5
# F#5
# B-3
# C#4
# F#4
# B-4
# C#5
# B-3
# F#5
# C#4
# B-5
# F#4
# C#6
# B-4
# E-6
# C#6
# C6
# B-5
# C6
# C4
# B-5
# E4
# G#5
# G4
# F#5
# C5
# G#5
# F#5
# F5
# E5
# C4
# E4
# G4
# C5
# F5
# C3
# G5
# E3
# G#5
# G3
# B-5
# C4
# G#5
# G5
# F5
# E5
# F5
# G5
# G#5
# B-5
# C6
# D6
# C5
# E6
# F5
# F6
# G#5
# C5
# F5
# G#5
# C6
# F6
# G#6
# C4
# G#6
# F4
# C6
# F6
# G#6
# C7
# G#6
# G6
# C5
# E6
# F5
# F6
# G#5
# C5
# F5
# G#5
# C6
# F6
# G#6
# C4
# G#6
# F4
# C6
# F6
# G#6
# C7
# G#6
# G6
# C5
# E6
# F5
# F6
# G#5
# C5
# F5
# G#5
# C6
# F6
# G#6
# C4
# G#6
# F4
# C6
# F6
# G#6
# C7
# G#6
# G6
# C5
# E6
# F5
# F6
# G#5
# C5
# F5
# G#5
# C6
# F6
# G#6
# C4
# G#6
# F4
# C6
# F6
# G#6
# C7
# G#6
# G6
# C4
# E6
# F6
# F3
# C6
# F6
# G#6
# C7
# G#6
# G6
# C3
# E6
# F6
# F2
# C6
# F6
# G#6
# C7
# G#6
# G6
# C2
# E6
# F6
# F1
# C6
# F6
# C2
# G#6
# C7
# F1
# G#6
# G6
# C2
# E6
# C7
# F1
# G#6
# G#1
# G6
# C2
# E6
# F2
# C7
# F1
# G#6
# G#1
# G6
# C2
# E6
# F2
# C7
# F1
# G#6
# G#1
# F6
# C2
# C6
# F2
# G#6
# F1
# F6
# G#1
# C6
# C2
# G#5
# F2
# F6
# F1
# C6
# G#1
# G#5
# C2
# F5
# F2
# C6
# F1
# G#5
# G#1
# F5
# C2
# C5
# F2
# G#5
# F1
# F5
# G#1
# C5
# C2
# G#4
# F2
# F5
# F1
# C5
# G#1
# G#4
# C2
# F4
# F2
# C5
# F1
# G#4
# G#1
# F4
# C2
# C4
# F2
# G#4
# F1
# F4
# G#1
# C4
# C2
# G#3
# F2
# F4
# F1
# C4
# G#1
# G#3
# C2
# F3
# F2
# C4
# F1
# G#3
# G#1
# F3
# C2
# C3
# F2
# G#3
# F3
# C3
# G#2
# F3
# C3
# G#2
# C3

# %%
def one_hot_encode(vector, all_values):
    encoded_vectors = []
    int_to_index = dict((c, i) for i, c in enumerate(all_values))
    for i in vector:
        zero = [0] * (len(all_values) - 1)
        zero.insert(int_to_index[i], 1)
        encoded_vectors.append(zero)

    return encoded_vectors

# %%
from numpy import argmax


def one_hot_decode(vector, all_values):
    decoded_vector = []
    index_to_int = dict((i, c) for i, c in enumerate(all_values))
    decoded_vector.append(index_to_int[argmax(vector)])
    return decoded_vector

# %%
segment_length = 64


def make_segments(data_array, unique_values, seq_length=segment_length):
    input_seq = []
    output_seq = []

    processed_data = one_hot_encode(data_array, unique_values)

    for i in range(0, len(processed_data) - seq_length, 1):
        input_seq.append([processed_data[i : i + seq_length]])
        output_seq.append(processed_data[seq_length + i])

    del processed_data
    gc.collect()

    input_seq = np.reshape(
        input_seq, (len(input_seq), segment_length, len(unique_values))
    )
    output_seq = np.array(output_seq)

    return input_seq, output_seq

# %%
note_model_data = make_segments(data_array=note_data, unique_values=unique_notes)
offset_model_data = make_segments(data_array=offset_data, unique_values=unique_offsets)
duration_model_data = make_segments(
    data_array=duration_data, unique_values=unique_durations
)

# %%
X_train_note, X_test_note, y_train_note, y_test_note = train_test_split(
    note_model_data[0], note_model_data[1], test_size=0.2
)
X_train_off, X_test_off, y_train_off, y_test_off = train_test_split(
    offset_model_data[0], offset_model_data[1], test_size=0.2
)
X_train_dur, X_test_dur, y_train_dur, y_test_dur = train_test_split(
    duration_model_data[0], duration_model_data[1], test_size=0.2
)

# %%
del note_model_data
del offset_model_data
del duration_model_data
gc.collect()
# Out:
# 0

# %%
def make_model(input_shape, output_shape):
    model = Sequential()
    model.add(CuDNNLSTM(512, input_shape=input_shape, return_sequences=False))
    model.add(Dropout(0.25))
    model.add(Dense(128))
    model.add(Dense(output_shape, activation="softmax"))

    model.compile(
        loss="categorical_crossentropy",
        optimizer=Adam(learning_rate=0.001),
        metrics=["accuracy"],
    )
    return model

# %%
model_notes = make_model(
    input_shape=(segment_length, unique_note_number), output_shape=unique_note_number
)
model_offsets = make_model(
    input_shape=(segment_length, unique_offset_number),
    output_shape=unique_offset_number,
)
model_durations = make_model(
    input_shape=(segment_length, uenique_duration_number),
    output_shape=unique_duration_number,
)

# %%
my_callbacks = [tf.keras.callbacks.EarlyStopping(patience=2)]

# %%
history_note = model_notes.fit(
    X_train_note, y_train_note, epochs=150, validation_split=0.2, callbacks=my_callbacks
)
# Out:
# Epoch 1/150
# 2022-12-05 15:49:46.922566: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 111/111 [==============================] - ETA: 0s - loss: 4.2749 - accuracy: 0.0649
# 2022-12-05 15:49:50.792524: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 111/111 [==============================] - 5s 37ms/step - loss: 4.2749 - accuracy: 0.0649 - val_loss: 3.8869 - val_accuracy: 0.1071
# Epoch 2/150
# 111/111 [==============================] - 4s 34ms/step - loss: 3.6517 - accuracy: 0.1258 - val_loss: 3.4968 - val_accuracy: 0.1229
# Epoch 3/150
# 111/111 [==============================] - 4s 33ms/step - loss: 3.3171 - accuracy: 0.1588 - val_loss: 3.2985 - val_accuracy: 0.1623
# Epoch 4/150
# 111/111 [==============================] - 4s 32ms/step - loss: 3.1162 - accuracy: 0.1783 - val_loss: 3.2192 - val_accuracy: 0.1488
# Epoch 5/150
# 111/111 [==============================] - 4s 33ms/step - loss: 2.9499 - accuracy: 0.2042 - val_loss: 3.1194 - val_accuracy: 0.1759
# Epoch 6/150
# 111/111 [==============================] - 4s 33ms/step - loss: 2.7891 - accuracy: 0.2347 - val_loss: 3.0167 - val_accuracy: 0.1928
# Epoch 7/150
# 111/111 [==============================] - 4s 33ms/step - loss: 2.6216 - accuracy: 0.2694 - val_loss: 2.8691 - val_accuracy: 0.2221
# Epoch 8/150
# 111/111 [==============================] - 4s 33ms/step - loss: 2.4723 - accuracy: 0.2948 - val_loss: 2.8168 - val_accuracy: 0.2570
# Epoch 9/150
# 111/111 [==============================] - 4s 33ms/step - loss: 2.3052 - accuracy: 0.3374 - val_loss: 2.7278 - val_accuracy: 0.2537
# Epoch 10/150
# 111/111 [==============================] - 4s 32ms/step - loss: 2.1461 - accuracy: 0.3766 - val_loss: 2.6559 - val_accuracy: 0.2807
# Epoch 11/150
# 111/111 [==============================] - 4s 33ms/step - loss: 1.9594 - accuracy: 0.4296 - val_loss: 2.5209 - val_accuracy: 0.3371
# Epoch 12/150
# 111/111 [==============================] - 4s 33ms/step - loss: 1.7919 - accuracy: 0.4764 - val_loss: 2.4631 - val_accuracy: 0.3405
# Epoch 13/150
# 111/111 [==============================] - 4s 32ms/step - loss: 1.6165 - accuracy: 0.5233 - val_loss: 2.3813 - val_accuracy: 0.3856
# Epoch 14/150
# 111/111 [==============================] - 4s 33ms/step - loss: 1.4604 - accuracy: 0.5687 - val_loss: 2.3912 - val_accuracy: 0.3867
# Epoch 15/150
# 111/111 [==============================] - 4s 33ms/step - loss: 1.2989 - accuracy: 0.6045 - val_loss: 2.3628 - val_accuracy: 0.4149
# Epoch 16/150
# 111/111 [==============================] - 4s 33ms/step - loss: 1.1425 - accuracy: 0.6525 - val_loss: 2.3225 - val_accuracy: 0.4318
# Epoch 17/150
# 111/111 [==============================] - 4s 33ms/step - loss: 1.0066 - accuracy: 0.6883 - val_loss: 2.3063 - val_accuracy: 0.4476
# Epoch 18/150
# 111/111 [==============================] - 4s 33ms/step - loss: 0.8785 - accuracy: 0.7275 - val_loss: 2.3583 - val_accuracy: 0.4464
# Epoch 19/150
# 111/111 [==============================] - 4s 33ms/step - loss: 0.7449 - accuracy: 0.7715 - val_loss: 2.3402 - val_accuracy: 0.4622

# %%
history_offset = model_offsets.fit(
    X_train_off, y_train_off, epochs=150, validation_split=0.2, callbacks=my_callbacks
)
# Out:
# Epoch 1/150
# 2022-12-05 15:54:48.405980: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 111/111 [==============================] - ETA: 0s - loss: 0.8595 - accuracy: 0.6612
# 2022-12-05 15:54:52.661210: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 111/111 [==============================] - 5s 38ms/step - loss: 0.8595 - accuracy: 0.6612 - val_loss: 0.7417 - val_accuracy: 0.6697
# Epoch 2/150
# 111/111 [==============================] - 4s 33ms/step - loss: 0.5919 - accuracy: 0.7616 - val_loss: 0.5300 - val_accuracy: 0.7745
# Epoch 3/150
# 111/111 [==============================] - 4s 33ms/step - loss: 0.5185 - accuracy: 0.8071 - val_loss: 0.4942 - val_accuracy: 0.8117
# Epoch 4/150
# 111/111 [==============================] - 4s 33ms/step - loss: 0.4867 - accuracy: 0.8195 - val_loss: 0.4441 - val_accuracy: 0.8343
# Epoch 5/150
# 111/111 [==============================] - 4s 34ms/step - loss: 0.4613 - accuracy: 0.8440 - val_loss: 0.4250 - val_accuracy: 0.8681
# Epoch 6/150
# 111/111 [==============================] - 4s 36ms/step - loss: 0.4445 - accuracy: 0.8477 - val_loss: 0.4179 - val_accuracy: 0.8557
# Epoch 7/150
# 111/111 [==============================] - 4s 34ms/step - loss: 0.4321 - accuracy: 0.8511 - val_loss: 0.4070 - val_accuracy: 0.8568
# Epoch 8/150
# 111/111 [==============================] - 4s 33ms/step - loss: 0.4188 - accuracy: 0.8584 - val_loss: 0.4192 - val_accuracy: 0.8579
# Epoch 9/150
# 111/111 [==============================] - 4s 33ms/step - loss: 0.4094 - accuracy: 0.8584 - val_loss: 0.4291 - val_accuracy: 0.8534

# %%
history_duration = model_durations.fit(
    X_train_dur, y_train_dur, epochs=150, validation_split=0.2, callbacks=my_callbacks
)
# Out:
# Epoch 1/150
# 2022-12-05 15:55:36.530289: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 111/111 [==============================] - ETA: 0s - loss: 0.5921 - accuracy: 0.8702
# 2022-12-05 15:55:40.693810: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 111/111 [==============================] - 5s 39ms/step - loss: 0.5921 - accuracy: 0.8702 - val_loss: 0.5061 - val_accuracy: 0.8828
# Epoch 2/150
# 111/111 [==============================] - 4s 34ms/step - loss: 0.5046 - accuracy: 0.8821 - val_loss: 0.4977 - val_accuracy: 0.8839
# Epoch 3/150
# 111/111 [==============================] - 4s 34ms/step - loss: 0.4777 - accuracy: 0.8824 - val_loss: 0.4641 - val_accuracy: 0.8873
# Epoch 4/150
# 111/111 [==============================] - 4s 34ms/step - loss: 0.4649 - accuracy: 0.8835 - val_loss: 0.4798 - val_accuracy: 0.8816
# Epoch 5/150
# 111/111 [==============================] - 4s 33ms/step - loss: 0.4511 - accuracy: 0.8860 - val_loss: 0.4499 - val_accuracy: 0.8861
# Epoch 6/150
# 111/111 [==============================] - 4s 34ms/step - loss: 0.4429 - accuracy: 0.8846 - val_loss: 0.4560 - val_accuracy: 0.8861
# Epoch 7/150
# 111/111 [==============================] - 4s 34ms/step - loss: 0.4325 - accuracy: 0.8880 - val_loss: 0.4431 - val_accuracy: 0.8884
# Epoch 8/150
# 111/111 [==============================] - 4s 37ms/step - loss: 0.4250 - accuracy: 0.8908 - val_loss: 0.4359 - val_accuracy: 0.8906
# Epoch 9/150
# 111/111 [==============================] - 4s 34ms/step - loss: 0.4143 - accuracy: 0.8934 - val_loss: 0.4382 - val_accuracy: 0.8940
# Epoch 10/150
# 111/111 [==============================] - 4s 33ms/step - loss: 0.4080 - accuracy: 0.8948 - val_loss: 0.4193 - val_accuracy: 0.8940
# Epoch 11/150
# 111/111 [==============================] - 4s 33ms/step - loss: 0.3954 - accuracy: 0.8962 - val_loss: 0.4260 - val_accuracy: 0.8952
# Epoch 12/150
# 111/111 [==============================] - 4s 34ms/step - loss: 0.3835 - accuracy: 0.8976 - val_loss: 0.4074 - val_accuracy: 0.8952
# Epoch 13/150
# 111/111 [==============================] - 4s 33ms/step - loss: 0.3676 - accuracy: 0.8993 - val_loss: 0.4021 - val_accuracy: 0.8918
# Epoch 14/150
# 111/111 [==============================] - 4s 34ms/step - loss: 0.3592 - accuracy: 0.8996 - val_loss: 0.3795 - val_accuracy: 0.8952
# Epoch 15/150
# 111/111 [==============================] - 4s 33ms/step - loss: 0.3458 - accuracy: 0.9061 - val_loss: 0.3966 - val_accuracy: 0.8963
# Epoch 16/150
# 111/111 [==============================] - 4s 36ms/step - loss: 0.3468 - accuracy: 0.9038 - val_loss: 0.3662 - val_accuracy: 0.9019
# Epoch 17/150
# 111/111 [==============================] - 4s 34ms/step - loss: 0.3238 - accuracy: 0.9075 - val_loss: 0.3506 - val_accuracy: 0.9064
# Epoch 18/150
# 111/111 [==============================] - 4s 35ms/step - loss: 0.3188 - accuracy: 0.9148 - val_loss: 0.3713 - val_accuracy: 0.8963
# Epoch 19/150
# 111/111 [==============================] - 4s 33ms/step - loss: 0.3122 - accuracy: 0.9126 - val_loss: 0.3429 - val_accuracy: 0.9087
# Epoch 20/150
# 111/111 [==============================] - 4s 33ms/step - loss: 0.3188 - accuracy: 0.9075 - val_loss: 0.3627 - val_accuracy: 0.9008
# Epoch 21/150
# 111/111 [==============================] - 4s 33ms/step - loss: 0.3028 - accuracy: 0.9165 - val_loss: 0.3463 - val_accuracy: 0.9053

# %%
def sample(preds, temperature=1.0):
    """Helper function to sample an index from a probability array."""
    preds = np.asarray(preds).astype("float64")
    preds = np.exp(np.log(preds) / temperature)
    preds = preds / np.sum(preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
def music_maker(seed_vec, model_type, number_unique, unique, diversity, num_notes=64):
    music = []
    arr = np.zeros((len(seed_vec) + num_notes, number_unique))
    for c, i in enumerate(seed_vec):
        arr[c] = i

    for i in range(0, num_notes, 1):
        d_arr = np.zeros(number_unique)
        pred = model_type.predict(
            np.reshape(
                arr[i : len(arr) - num_notes + i],
                (1, len(arr[i : len(arr) - num_notes + i]), number_unique),
            ),
            verbose=0,
        )[0]
        diverse = sample(pred, diversity)
        d_arr[diverse] = 1
        music.append(one_hot_decode(d_arr, all_values=unique)[0])

        arr[len(seed_vec) + i] = d_arr

    return music

# %%
randnum = random.randrange(0, len(X_test_note))
test_note = X_test_note[randnum]
test_offset = X_test_off[randnum]
test_dur = X_test_dur[randnum]
generated_music_note = music_maker(
    test_note, model_notes, unique_note_number, unique_notes, 0.7
)
generated_music_offset = music_maker(
    test_offset, model_offsets, unique_offset_number, unique_offsets, 0.7
)
generated_music_duration = music_maker(
    test_dur, model_durations, unique_duration_number, unique_durations, 0.2
)
# Out:
# 2022-12-05 15:57:03.373829: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2022-12-05 15:57:06.059432: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2022-12-05 15:57:07.757926: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
seed_notes = []
seed_offsets = []
seed_durations = []
for n in test_note:
    seed_notes.append(one_hot_decode(n, unique_notes)[0])
for o in test_offset:
    seed_offsets.append(one_hot_decode(o, unique_offsets)[0])
for d in test_dur:
    seed_durations.append(one_hot_decode(d, unique_durations)[0])

# %%
def to_midi(notes, offsets, durations):
    """
    Summary:
    Takes midi metadata and converts it to a Music21 stream. The stream can then easily be converted into a midi file.

    Parameters:
    metadata: midi metadata (notes,chords,offsets)

    Returns:
    list: Music21 stream object
    """
    offset = offsets[0]
    s = stream.Stream()
    for i, ele in enumerate(notes):
        if ele[0].isalpha():
            n = note.Note(ele)
            try:
                n.quarterLength = float(durations[i])
            except:
                n.quarterLength = Fraction(durations[i])

            s.insert(offset, n)

            offset += offsets[i]
        else:
            chords = list(map(int, ele.split(".")))
            c = chord.Chord(chords)

            try:
                c.quarterLength = float(durations[i])
            except:
                c.quarterLength = Fraction(durations[i])

            s.insert(offset, c)

            offset += offsets[i]
    return s

# %%
to_midi(generated_music_note, generated_music_offset, generated_music_duration).write(
    "midi", "generated_classical.mid"
)
to_midi(seed_notes, seed_offsets, seed_durations).write("midi", "seed_classical.mid")
# Out:
# 'seed_classical.mid'
